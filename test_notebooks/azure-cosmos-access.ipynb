# %% [markdown]
# # Accessing Azure Cosmos DB
# The purpose of this notebook is to showcase how to use the Cosmos DB through Python \
# It will also serve as the registering of the students for the first time in the database

# %% [markdown]
# ## 1. Getting documents out of CSV data

# %%
import pandas as pd
import azure.identity
import azure.cosmos
from dotenv import load_dotenv
import os

# %%
students_df = pd.read_csv("../data/students.csv")
students_df
# Out:
#          id        first_name          last_name
# 0   2109020            Karina     Campos Almeida
# 1   2009017  Christian Javier        Can Montero
# 2   2109022      Jesús Javier            Can Noh
# 3   2109041     Cesar Orlando      Correa Castro
# 4   2109062   Hector de Jesús  Fernández Zanatta
# 5   2109084           Gabriel       Islas Peraza
# 6   2109165      Jair Armando  Martínez Castillo
# 7   1909123           Eduardo     Mendoza Vargas
# 8   2109107            Fatima    Miranda Pestaña
# 9   2109108           Mariano    Miranda Sánchez
# 10  2109111     Luis Fernando   Monterrubio Cota
# 11  2009151       Diana Laura       Olivas Marin
# 12  2109120          Mauricio     Pacheco Lizama
# 13  2109136      Miguel Angel       Sánchez Piña
# 14  2109146         Juan José            Tec Tun
# 15  2109155           Cynthia       Vidal Ovando

# %%
students_df = students_df.astype({"id":"str"})

# %%
students_df["email"] = students_df["id"] + "@upy.edu.mx"
students_df
# Out:
#          id        first_name          last_name               email
# 0   2109020            Karina     Campos Almeida  2109020@upy.edu.mx
# 1   2009017  Christian Javier        Can Montero  2009017@upy.edu.mx
# 2   2109022      Jesús Javier            Can Noh  2109022@upy.edu.mx
# 3   2109041     Cesar Orlando      Correa Castro  2109041@upy.edu.mx
# 4   2109062   Hector de Jesús  Fernández Zanatta  2109062@upy.edu.mx
# 5   2109084           Gabriel       Islas Peraza  2109084@upy.edu.mx
# 6   2109165      Jair Armando  Martínez Castillo  2109165@upy.edu.mx
# 7   1909123           Eduardo     Mendoza Vargas  1909123@upy.edu.mx
# 8   2109107            Fatima    Miranda Pestaña  2109107@upy.edu.mx
# 9   2109108           Mariano    Miranda Sánchez  2109108@upy.edu.mx
# 10  2109111     Luis Fernando   Monterrubio Cota  2109111@upy.edu.mx
# 11  2009151       Diana Laura       Olivas Marin  2009151@upy.edu.mx
# 12  2109120          Mauricio     Pacheco Lizama  2109120@upy.edu.mx
# 13  2109136      Miguel Angel       Sánchez Piña  2109136@upy.edu.mx
# 14  2109146         Juan José            Tec Tun  2109146@upy.edu.mx
# 15  2109155           Cynthia       Vidal Ovando  2109155@upy.edu.mx

# %%
student_document_list = students_df.to_dict(orient="records")
student_document_list
# Out:
# [{'id': '2109020',
#   'first_name': 'Karina',
#   'last_name': 'Campos Almeida',
#   'email': '2109020@upy.edu.mx'},
#  {'id': '2009017',
#   'first_name': 'Christian Javier',
#   'last_name': 'Can Montero',
#   'email': '2009017@upy.edu.mx'},
#  {'id': '2109022',
#   'first_name': 'Jesús Javier',
#   'last_name': 'Can Noh',
#   'email': '2109022@upy.edu.mx'},
#  {'id': '2109041',
#   'first_name': 'Cesar Orlando',
#   'last_name': 'Correa Castro',
#   'email': '2109041@upy.edu.mx'},
#  {'id': '2109062',
#   'first_name': 'Hector de Jesús',
#   'last_name': 'Fernández Zanatta',
#   'email': '2109062@upy.edu.mx'},
#  {'id': '2109084',
#   'first_name': 'Gabriel',
#   'last_name': 'Islas Peraza',
#   'email': '2109084@upy.edu.mx'},
#  {'id': '2109165',
#   'first_name': 'Jair Armando',
#   'last_name': 'Martínez Castillo',
#   'email': '2109165@upy.edu.mx'},
#  {'id': '1909123',
#   'first_name': 'Eduardo',
#   'last_name': 'Mendoza Vargas',
#   'email': '1909123@upy.edu.mx'},
#  {'id': '2109107',
#   'first_name': 'Fatima',
#   'last_name': 'Miranda Pestaña',
#   'email': '2109107@upy.edu.mx'},
#  {'id': '2109108',
#   'first_name': 'Mariano',
#   'last_name': 'Miranda Sánchez',
#   'email': '2109108@upy.edu.mx'},
#  {'id': '2109111',
#   'first_name': 'Luis Fernando',
#   'last_name': 'Monterrubio Cota',
#   'email': '2109111@upy.edu.mx'},
#  {'id': '2009151',
#   'first_name': 'Diana Laura',
#   'last_name': 'Olivas Marin',
#   'email': '2009151@upy.edu.mx'},
#  {'id': '2109120',
#   'first_name': 'Mauricio',
#   'last_name': 'Pacheco Lizama',
#   'email': '2109120@upy.edu.mx'},
#  {'id': '2109136',
#   'first_name': 'Miguel Angel',
#   'last_name': 'Sánchez Piña',
#   'email': '2109136@upy.edu.mx'},
#  {'id': '2109146',
#   'first_name': 'Juan José',
#   'last_name': 'Tec Tun',
#   'email': '2109146@upy.edu.mx'},
#  {'id': '2109155',
#   'first_name': 'Cynthia',
#   'last_name': 'Vidal Ovando',
#   'email': '2109155@upy.edu.mx'}]

# %% [markdown]
# ## 2. Uploading records

# %%
load_dotenv("../.env")
# Out:
# True

# %%
credential = azure.identity.AzureCliCredential()

# %%
client = azure.cosmos.CosmosClient(url=os.environ["COSMOS_URL"], credential=credential)

# %%
database = client.get_database_client("face-recog-db")

# %%
container = database.get_container_client("students")

# %%
upserted_items = []
for student in student_document_list:
    sent_item = container.upsert_item(student)
    upserted_items.append(sent_item)

# %%
upserted_items
# Out:
# [{'id': '2109020',
#   'first_name': 'Karina',
#   'last_name': 'Campos Almeida',
#   'email': '2109020@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYBAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYBAAAAAAAAAA==/',
#   '_etag': '"0100941a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2009017',
#   'first_name': 'Christian Javier',
#   'last_name': 'Can Montero',
#   'email': '2009017@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYCAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYCAAAAAAAAAA==/',
#   '_etag': '"0100951a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109022',
#   'first_name': 'Jesús Javier',
#   'last_name': 'Can Noh',
#   'email': '2109022@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYDAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYDAAAAAAAAAA==/',
#   '_etag': '"0100961a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109041',
#   'first_name': 'Cesar Orlando',
#   'last_name': 'Correa Castro',
#   'email': '2109041@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYEAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYEAAAAAAAAAA==/',
#   '_etag': '"0100971a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109062',
#   'first_name': 'Hector de Jesús',
#   'last_name': 'Fernández Zanatta',
#   'email': '2109062@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYFAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYFAAAAAAAAAA==/',
#   '_etag': '"0100981a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109084',
#   'first_name': 'Gabriel',
#   'last_name': 'Islas Peraza',
#   'email': '2109084@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYGAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYGAAAAAAAAAA==/',
#   '_etag': '"0100991a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109165',
#   'first_name': 'Jair Armando',
#   'last_name': 'Martínez Castillo',
#   'email': '2109165@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYHAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYHAAAAAAAAAA==/',
#   '_etag': '"01009a1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '1909123',
#   'first_name': 'Eduardo',
#   'last_name': 'Mendoza Vargas',
#   'email': '1909123@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYIAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYIAAAAAAAAAA==/',
#   '_etag': '"01009b1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109107',
#   'first_name': 'Fatima',
#   'last_name': 'Miranda Pestaña',
#   'email': '2109107@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYJAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYJAAAAAAAAAA==/',
#   '_etag': '"01009c1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109108',
#   'first_name': 'Mariano',
#   'last_name': 'Miranda Sánchez',
#   'email': '2109108@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYKAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYKAAAAAAAAAA==/',
#   '_etag': '"01009d1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109111',
#   'first_name': 'Luis Fernando',
#   'last_name': 'Monterrubio Cota',
#   'email': '2109111@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYLAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYLAAAAAAAAAA==/',
#   '_etag': '"01009e1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2009151',
#   'first_name': 'Diana Laura',
#   'last_name': 'Olivas Marin',
#   'email': '2009151@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYMAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYMAAAAAAAAAA==/',
#   '_etag': '"01009f1a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109120',
#   'first_name': 'Mauricio',
#   'last_name': 'Pacheco Lizama',
#   'email': '2109120@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYNAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYNAAAAAAAAAA==/',
#   '_etag': '"0100a01a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109136',
#   'first_name': 'Miguel Angel',
#   'last_name': 'Sánchez Piña',
#   'email': '2109136@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYOAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYOAAAAAAAAAA==/',
#   '_etag': '"0100a11a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109146',
#   'first_name': 'Juan José',
#   'last_name': 'Tec Tun',
#   'email': '2109146@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYPAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYPAAAAAAAAAA==/',
#   '_etag': '"0100a21a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985},
#  {'id': '2109155',
#   'first_name': 'Cynthia',
#   'last_name': 'Vidal Ovando',
#   'email': '2109155@upy.edu.mx',
#   '_rid': 'Pz1aANVRYJYQAAAAAAAAAA==',
#   '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYQAAAAAAAAAA==/',
#   '_etag': '"0100a31a-0000-5200-0000-671e1a010000"',
#   '_attachments': 'attachments/',
#   '_ts': 1730025985}]

# %% [markdown]
# ## 3. Reading items

# %%
item = container.read_item(item = "2109084", partition_key = "2109084")

# %%
item
# Out:
# {'id': '2109084',
#  'first_name': 'Gabriel',
#  'last_name': 'Islas Peraza',
#  'email': '2109084@upy.edu.mx',
#  '_rid': 'Pz1aANVRYJYGAAAAAAAAAA==',
#  '_self': 'dbs/Pz1aAA==/colls/Pz1aANVRYJY=/docs/Pz1aANVRYJYGAAAAAAAAAA==/',
#  '_etag': '"0100991a-0000-5200-0000-671e1a010000"',
#  '_attachments': 'attachments/',
#  '_ts': 1730025985}

# %% [markdown]
# ## 4. Querying

# %%
query = "SELECT s.first_name, s.last_name FROM students s WHERE StringToNumber(s.id) < 2109000"
results = container.query_items(query = query, enable_cross_partition_query=True)

# %%
items = [item for item in results]

# %%
items
# Out:
# [{'first_name': 'Christian Javier', 'last_name': 'Can Montero'},
#  {'first_name': 'Eduardo', 'last_name': 'Mendoza Vargas'},
#  {'first_name': 'Diana Laura', 'last_name': 'Olivas Marin'}]
